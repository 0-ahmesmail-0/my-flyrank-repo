# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
"""
I am choosing Lane 2: Refresh / Content Opportunity Scoring.

In any active content strategy, editorial teams face a massive bottleneck: they have hundreds of published pages
but limited time to manually audit and update them. Identifying which pages are losing search traction,
yet still retain enough search demand to warrant a manual rewrite, is a high-value prioritization problem.
Improving this selection process directly translates to better resource allocation and traffic preservation.
"""
# Out:
# '\nI am choosing Lane 2: Refresh / Content Opportunity Scoring.  \n\nIn any active content strategy, editorial teams face a massive bottleneck: they have hundreds of published pages \nbut limited time to manually audit and update them. Identifying which pages are losing search traction,\nyet still retain enough search demand to warrant a manual rewrite, is a high-value prioritization problem. \nImproving this selection process directly translates to better resource allocation and traffic preservation.\n'

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
"""
1.It determines which specific content pages the editorial/content team should prioritize for an update or rewrite first.
2.Content managers, SEO specialists, and copywriters.
3.False Positive (recommending a dead page): A writer spends 3 to 5 hours rewriting a page that has no real search demand or
 is undergoing seasonal/natural decline, wasting valuable editorial budget.
False Negative (missing a decay risk): High-performing content decays quietly, resulting in a permanent loss of
organic traffic, conversions, and search engine authority.

"""
# Out:
# '\n1.It determines which specific content pages the editorial/content team should prioritize for an update or rewrite first.\n2.Content managers, SEO specialists, and copywriters.\n3.False Positive (recommending a dead page): A writer spends 3 to 5 hours rewriting a page that has no real search demand or\n is undergoing seasonal/natural decline, wasting valuable editorial budget.\nFalse Negative (missing a decay risk): High-performing content decays quietly, resulting in a permanent loss of \norganic traffic, conversions, and search engine authority.\n\n'

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")  # move from notebooks/ to the repo root

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")


df = pd.read_csv("../data/raw/content_refresh_anonymized.csv")

total_pages = len(df)
declining_pages = len(df[df['trend_direction'] == 'down'])
declining_pct = (declining_pages / total_pages) * 100

# 2. High-exposure pages at risk (pages with >= 500 impressions in past 90 days that are declining)
high_exposure_declining = len(df[(df['trend_direction'] == 'down') & (df['impressions_90d'] >= 500)])

print(f"Total Pages Analysed: {total_pages:,}")
print(f"Declining Pages: {declining_pages:,} ({declining_pct:.1f}%)")
print(f"High-Exposure Declining Pages (>=500 impressions): {high_exposure_declining:,}")
# Out:
# Working dir: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# Starter data found. You're ready.
# Total Pages Analysed: 30,000
# Declining Pages: 16,262 (54.2%)
# High-Exposure Declining Pages (>=500 impressions): 9,961

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
'''
What I can claim: We can establish observed associations and directional trends indicating
which page performance metrics (such as CTR, average position, and age) correlate with historical traffic declines.
The output is strictly a decision-support tool to prioritize human editorial queues based on these observed patterns.

What I cannot claim: We cannot claim causal proof (i.e., we cannot prove that executing a content refresh will cause a search traffic recovery).
We are not "predicting Google’s algorithm" or reverse-engineering search engine rankings; we are simply identifying pages that are
losing search traction relative to their historical performance.
'''
# Out:
# '\nWhat I can claim: We can establish observed associations and directional trends indicating\nwhich page performance metrics (such as CTR, average position, and age) correlate with historical traffic declines. \nThe output is strictly a decision-support tool to prioritize human editorial queues based on these observed patterns.  \n\nWhat I cannot claim: We cannot claim causal proof (i.e., we cannot prove that executing a content refresh will cause a search traffic recovery). \nWe are not "predicting Google’s algorithm" or reverse-engineering search engine rankings; we are simply identifying pages that are\nlosing search traction relative to their historical performance.\n'

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
